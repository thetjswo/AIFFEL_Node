# %%
import numpy as np
from scipy.signal import convolve2d
from skimage.io import imread, imshow
from skimage.color import rgb2gray

# %%
cat = rgb2gray(imread('/Users/leeseonjae/Downloads/cat.jpeg'))

# %%
cat.shape
# Out:
# (183, 275)

# %%
cat
# Out:
# array([[0.00392157, 0.00392157, 0.00392157, ..., 0.00392157, 0.00392157,
#         0.00392157],
#        [0.00392157, 0.00392157, 0.00392157, ..., 0.00392157, 0.00392157,
#         0.00392157],
#        [0.00392157, 0.00392157, 0.00392157, ..., 0.00392157, 0.00392157,
#         0.00392157],
#        ...,
#        [0.03110471, 0.03110471, 0.03110471, ..., 0.01541843, 0.01541843,
#         0.01541843],
#        [0.03110471, 0.03110471, 0.03110471, ..., 0.01541843, 0.01541843,
#         0.01541843],
#        [0.03110471, 0.03110471, 0.03110471, ..., 0.01541843, 0.01541843,
#         0.01541843]])

# %%
imshow(cat)

# %%
edge = np.array([[-1, -1, -1],
               [-1, 8, -1],
               [-1, -1, -1]])

sharpen = np.array([[0, -1, 0],
                  [-1, 5, -1],
                  [0, -1, 0]])

blur = (1 / 16.0) * np.array([[1., 2., 1.],
                            [2., 4., 2.],
                            [1., 2., 1.]])

# %%
edge_im = convolve2d(cat, edge, 'valid')

# %%
imshow(edge_im)

# %%
sharp_im = convolve2d(cat, sharpen, 'valid')

# %%
imshow(sharp_im)

# %%
blur_im = convolve2d(cat, blur, 'valid')

# %%
imshow(blur)
