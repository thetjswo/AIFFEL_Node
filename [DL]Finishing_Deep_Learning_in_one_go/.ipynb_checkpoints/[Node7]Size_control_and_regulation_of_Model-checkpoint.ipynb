# %%
from keras.datasets import imdb
import numpy as np

def one_hot_encoding(data, dim=10000): # 아래 imdb.load_data의 num_words를 10000으로 설정할 예정이기 때문에 dim도 10000으로 맞춰줍니다.
  results = np.zeros((len(data), dim))
  for i, d in enumerate(data):
    results[i, d] = 1.
  return results

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)

x_train = one_hot_encoding(train_data)
x_test = one_hot_encoding(test_data)

y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %%
import tensorflow as tf
from tensorflow.keras import models, layers

model = models.Sequential()
model.add(layers.Dense(128, activation='relu', input_shape=(10000, ), name='input'))
model.add(layers.Dense(128, activation='relu', name='hidden'))
model.add(layers.Dense(1, activation='sigmoid', name='output'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (Dense)               (None, 128)               1280128
#
#  hidden (Dense)              (None, 128)               16512
#
#  output (Dense)              (None, 1)                 129
#
# =================================================================
# Total params: 1296769 (4.95 MB)
# Trainable params: 1296769 (4.95 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train,
                    epochs=30,
                    batch_size=512,
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 49/49 [==============================] - 4s 71ms/step - loss: 0.4323 - accuracy: 0.8065 - val_loss: 0.3895 - val_accuracy: 0.8306
# Epoch 2/30
# 49/49 [==============================] - 1s 30ms/step - loss: 0.2282 - accuracy: 0.9119 - val_loss: 0.3093 - val_accuracy: 0.8762
# Epoch 3/30
# 49/49 [==============================] - 1s 27ms/step - loss: 0.1703 - accuracy: 0.9342 - val_loss: 0.3010 - val_accuracy: 0.8816
# Epoch 4/30
# 49/49 [==============================] - 1s 28ms/step - loss: 0.1195 - accuracy: 0.9546 - val_loss: 0.4441 - val_accuracy: 0.8398
# Epoch 5/30
# 49/49 [==============================] - 1s 30ms/step - loss: 0.0840 - accuracy: 0.9714 - val_loss: 0.3689 - val_accuracy: 0.8750
# Epoch 6/30
# 49/49 [==============================] - 1s 27ms/step - loss: 0.0448 - accuracy: 0.9858 - val_loss: 0.6122 - val_accuracy: 0.8375
# Epoch 7/30
# 49/49 [==============================] - 1s 28ms/step - loss: 0.0400 - accuracy: 0.9890 - val_loss: 0.5034 - val_accuracy: 0.8742
# Epoch 8/30
# 49/49 [==============================] - 1s 29ms/step - loss: 0.0416 - accuracy: 0.9900 - val_loss: 0.5189 - val_accuracy: 0.8712
# Epoch 9/30
# 49/49 [==============================] - 2s 31ms/step - loss: 0.0034 - accuracy: 0.9995 - val_loss: 0.6957 - val_accuracy: 0.8714
# Epoch 10/30
# 49/49 [==============================] - 1s 27ms/step - loss: 0.0427 - accuracy: 0.9918 - val_loss: 0.6692 - val_accuracy: 0.8715
# Epoch 11/30
# 49/49 [==============================] - 1s 27ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.8095 - val_accuracy: 0.8633
# Epoch 12/30
# 49/49 [==============================] - 1s 26ms/step - loss: 0.0406 - accuracy: 0.9940 - val_loss: 0.7907 - val_accuracy: 0.8675
# Epoch 13/30
# 49/49 [==============================] - 1s 26ms/step - loss: 3.8650e-04 - accuracy: 1.0000 - val_loss: 0.8916 - val_accuracy: 0.8673
# Epoch 14/30
# 49/49 [==============================] - 1s 26ms/step - loss: 1.2764e-04 - accuracy: 1.0000 - val_loss: 1.0282 - val_accuracy: 0.8635
# Epoch 15/30
# 49/49 [==============================] - 1s 27ms/step - loss: 0.0444 - accuracy: 0.9938 - val_loss: 1.0428 - val_accuracy: 0.8645
# Epoch 16/30
# 49/49 [==============================] - 1s 27ms/step - loss: 4.3794e-05 - accuracy: 1.0000 - val_loss: 1.0723 - val_accuracy: 0.8653
# Epoch 17/30
# 49/49 [==============================] - 1s 31ms/step - loss: 2.1240e-05 - accuracy: 1.0000 - val_loss: 1.1511 - val_accuracy: 0.8663
# Epoch 18/30
# 49/49 [==============================] - 1s 29ms/step - loss: 8.1001e-06 - accuracy: 1.0000 - val_loss: 1.2728 - val_accuracy: 0.8666
# Epoch 19/30
# 49/49 [==============================] - 1s 29ms/step - loss: 0.0626 - accuracy: 0.9939 - val_loss: 1.1499 - val_accuracy: 0.8663
# Epoch 20/30
# 49/49 [==============================] - 1s 28ms/step - loss: 7.0781e-06 - accuracy: 1.0000 - val_loss: 1.1817 - val_accuracy: 0.8670
# Epoch 21/30
# 49/49 [==============================] - 1s 29ms/step - loss: 4.5236e-06 - accuracy: 1.0000 - val_loss: 1.2328 - val_accuracy: 0.8680
# Epoch 22/30
# 49/49 [==============================] - 1s 29ms/step - loss: 2.3826e-06 - accuracy: 1.0000 - val_loss: 1.3475 - val_accuracy: 0.8682
# Epoch 23/30
# 49/49 [==============================] - 2s 33ms/step - loss: 8.2999e-07 - accuracy: 1.0000 - val_loss: 1.4956 - val_accuracy: 0.8674
# Epoch 24/30
# 49/49 [==============================] - 2s 31ms/step - loss: 0.0586 - accuracy: 0.9940 - val_loss: 1.3662 - val_accuracy: 0.8666
# Epoch 25/30
# 49/49 [==============================] - 1s 30ms/step - loss: 9.4932e-07 - accuracy: 1.0000 - val_loss: 1.3720 - val_accuracy: 0.8669
# Epoch 26/30
# 49/49 [==============================] - 1s 28ms/step - loss: 6.3710e-07 - accuracy: 1.0000 - val_loss: 1.3820 - val_accuracy: 0.8670
# Epoch 27/30
# 49/49 [==============================] - 1s 29ms/step - loss: 4.5653e-07 - accuracy: 1.0000 - val_loss: 1.4139 - val_accuracy: 0.8666
# Epoch 28/30
# 49/49 [==============================] - 1s 25ms/step - loss: 2.5063e-07 - accuracy: 1.0000 - val_loss: 1.5115 - val_accuracy: 0.8676
# Epoch 29/30
# 49/49 [==============================] - 1s 27ms/step - loss: 1.0583e-07 - accuracy: 1.0000 - val_loss: 1.6194 - val_accuracy: 0.8674
# Epoch 30/30
# 49/49 [==============================] - 1s 23ms/step - loss: 4.7572e-08 - accuracy: 1.0000 - val_loss: 1.6891 - val_accuracy: 0.8676

# %%
import matplotlib.pyplot as plt

history_dict = history.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']
epochs = range(1, len(loss) + 1)

fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b--', label='train_loss')
ax1.plot(epochs, val_loss, 'r--', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, accuracy, 'b--', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r--', label='val_accuracy')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %%
b_model = models.Sequential()
b_model.add(layers.Dense(2048, activation='relu', input_shape=(10000, ), name='input3'))
b_model.add(layers.Dense(2048, activation='relu', name='hidden3'))
b_model.add(layers.Dense(1, activation='sigmoid', name='output3'))
b_model.compile(optimizer='rmsprop',
                loss='binary_crossentropy',
                metrics=['accuracy'])
b_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input3 (Dense)              (None, 2048)              20482048
#
#  hidden3 (Dense)             (None, 2048)              4196352
#
#  output3 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 24680449 (94.15 MB)
# Trainable params: 24680449 (94.15 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
b_model_history = b_model.fit(x_train, y_train,
                              epochs=30,
                              batch_size=512, 
                              validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 49/49 [==============================] - 19s 382ms/step - loss: 0.7894 - accuracy: 0.7799 - val_loss: 0.3360 - val_accuracy: 0.8500
# Epoch 2/30
# 49/49 [==============================] - 17s 354ms/step - loss: 0.2229 - accuracy: 0.9115 - val_loss: 0.3423 - val_accuracy: 0.8635
# Epoch 3/30
# 49/49 [==============================] - 17s 342ms/step - loss: 0.1230 - accuracy: 0.9570 - val_loss: 0.3340 - val_accuracy: 0.8878
# Epoch 4/30
# 49/49 [==============================] - 16s 320ms/step - loss: 0.0473 - accuracy: 0.9866 - val_loss: 0.4690 - val_accuracy: 0.8863
# Epoch 5/30
# 49/49 [==============================] - 15s 315ms/step - loss: 0.1722 - accuracy: 0.9840 - val_loss: 0.4473 - val_accuracy: 0.8799
# Epoch 6/30
# 49/49 [==============================] - 15s 311ms/step - loss: 7.7944e-04 - accuracy: 0.9999 - val_loss: 0.6388 - val_accuracy: 0.8823
# Epoch 7/30
# 49/49 [==============================] - 16s 333ms/step - loss: 0.2190 - accuracy: 0.9846 - val_loss: 0.5352 - val_accuracy: 0.8694
# Epoch 8/30
# 49/49 [==============================] - 16s 329ms/step - loss: 6.2786e-04 - accuracy: 1.0000 - val_loss: 0.7123 - val_accuracy: 0.8819
# Epoch 9/30
# 49/49 [==============================] - 18s 359ms/step - loss: 1.2160e-05 - accuracy: 1.0000 - val_loss: 0.8931 - val_accuracy: 0.8686
# Epoch 10/30
# 49/49 [==============================] - 17s 338ms/step - loss: 2.3011e-06 - accuracy: 1.0000 - val_loss: 0.8771 - val_accuracy: 0.8828
# Epoch 11/30
# 49/49 [==============================] - 16s 332ms/step - loss: 4.4874e-07 - accuracy: 1.0000 - val_loss: 1.0061 - val_accuracy: 0.8804
# Epoch 12/30
# 49/49 [==============================] - 15s 307ms/step - loss: 9.2822e-08 - accuracy: 1.0000 - val_loss: 1.1136 - val_accuracy: 0.8814
# Epoch 13/30
# 49/49 [==============================] - 16s 321ms/step - loss: 2.4519e-08 - accuracy: 1.0000 - val_loss: 1.1892 - val_accuracy: 0.8816
# Epoch 14/30
# 49/49 [==============================] - 16s 324ms/step - loss: 1.0686e-08 - accuracy: 1.0000 - val_loss: 1.2252 - val_accuracy: 0.8818
# Epoch 15/30
# 49/49 [==============================] - 17s 358ms/step - loss: 6.6725e-09 - accuracy: 1.0000 - val_loss: 1.2513 - val_accuracy: 0.8817
# Epoch 16/30
# 49/49 [==============================] - 17s 358ms/step - loss: 4.8716e-09 - accuracy: 1.0000 - val_loss: 1.2709 - val_accuracy: 0.8816
# Epoch 17/30
# 49/49 [==============================] - 16s 327ms/step - loss: 3.8695e-09 - accuracy: 1.0000 - val_loss: 1.2860 - val_accuracy: 0.8816
# Epoch 18/30
# 49/49 [==============================] - 17s 342ms/step - loss: 3.2118e-09 - accuracy: 1.0000 - val_loss: 1.2993 - val_accuracy: 0.8818
# Epoch 19/30
# 49/49 [==============================] - 16s 333ms/step - loss: 2.7700e-09 - accuracy: 1.0000 - val_loss: 1.3083 - val_accuracy: 0.8817
# Epoch 20/30
# 49/49 [==============================] - 17s 339ms/step - loss: 2.4323e-09 - accuracy: 1.0000 - val_loss: 1.3160 - val_accuracy: 0.8816
# Epoch 21/30
# 49/49 [==============================] - 16s 334ms/step - loss: 2.1628e-09 - accuracy: 1.0000 - val_loss: 1.3257 - val_accuracy: 0.8814
# Epoch 22/30
# 49/49 [==============================] - 16s 336ms/step - loss: 1.9698e-09 - accuracy: 1.0000 - val_loss: 1.3330 - val_accuracy: 0.8813
# Epoch 23/30
# 49/49 [==============================] - 17s 350ms/step - loss: 1.8152e-09 - accuracy: 1.0000 - val_loss: 1.3391 - val_accuracy: 0.8812
# Epoch 24/30
# 49/49 [==============================] - 19s 384ms/step - loss: 1.6770e-09 - accuracy: 1.0000 - val_loss: 1.3454 - val_accuracy: 0.8811
# Epoch 25/30
# 49/49 [==============================] - 17s 355ms/step - loss: 1.5681e-09 - accuracy: 1.0000 - val_loss: 1.3507 - val_accuracy: 0.8809
# Epoch 26/30
# 49/49 [==============================] - 18s 364ms/step - loss: 1.4789e-09 - accuracy: 1.0000 - val_loss: 1.3546 - val_accuracy: 0.8810
# Epoch 27/30
# 49/49 [==============================] - 17s 351ms/step - loss: 1.3851e-09 - accuracy: 1.0000 - val_loss: 1.3604 - val_accuracy: 0.8808
# Epoch 28/30
# 49/49 [==============================] - 17s 338ms/step - loss: 1.3198e-09 - accuracy: 1.0000 - val_loss: 1.3646 - val_accuracy: 0.8807
# Epoch 29/30
# 49/49 [==============================] - 17s 356ms/step - loss: 1.2578e-09 - accuracy: 1.0000 - val_loss: 1.3690 - val_accuracy: 0.8807
# Epoch 30/30
# 49/49 [==============================] - 16s 327ms/step - loss: 1.2073e-09 - accuracy: 1.0000 - val_loss: 1.3725 - val_accuracy: 0.8807

# %%
b_history_dict = b_model_history.history

b_loss = b_history_dict['loss']
b_val_loss = b_history_dict['val_loss']
epochs = range(1, len(b_loss) + 1)

fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, b_loss, 'b-', label='train_loss(large)')
ax1.plot(epochs, b_val_loss, 'r-', label='val_loss(large)')
ax1.plot(epochs, loss, 'b--', label='train_loss')
ax1.plot(epochs, val_loss, 'r--', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

b_accuracy = b_history_dict['accuracy']
b_val_accuracy = b_history_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, b_accuracy, 'b-', label='train_accuracy(large)')
ax2.plot(epochs, b_val_accuracy, 'r-', label='val_accuracy(large)')
ax2.plot(epochs, accuracy, 'b--', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r--', label='val_accuracy')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %%
s_model = models.Sequential()
s_model.add(layers.Dense(16, activation='relu', input_shape=(10000, ), name='input2'))
s_model.add(layers.Dense(16, activation='relu', name='hidden2'))
s_model.add(layers.Dense(1, activation='sigmoid', name='output2'))
s_model.compile(optimizer='rmsprop',
                loss='binary_crossentropy',
                metrics=['accuracy'])
s_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input2 (Dense)              (None, 16)                160016
#
#  hidden2 (Dense)             (None, 16)                272
#
#  output2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 160305 (626.19 KB)
# Trainable params: 160305 (626.19 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
s_model_history = s_model.fit(x_train, y_train,
                              epochs=30,
                              batch_size=512, 
                              validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 49/49 [==============================] - 2s 46ms/step - loss: 0.4680 - accuracy: 0.8220 - val_loss: 0.3419 - val_accuracy: 0.8826
# Epoch 2/30
# 49/49 [==============================] - 1s 12ms/step - loss: 0.2657 - accuracy: 0.9073 - val_loss: 0.2873 - val_accuracy: 0.8879
# Epoch 3/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.2050 - accuracy: 0.9259 - val_loss: 0.2798 - val_accuracy: 0.8890
# Epoch 4/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1713 - accuracy: 0.9405 - val_loss: 0.3104 - val_accuracy: 0.8761
# Epoch 5/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1484 - accuracy: 0.9488 - val_loss: 0.3062 - val_accuracy: 0.8818
# Epoch 6/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1322 - accuracy: 0.9544 - val_loss: 0.3286 - val_accuracy: 0.8766
# Epoch 7/30
# 49/49 [==============================] - 1s 10ms/step - loss: 0.1171 - accuracy: 0.9602 - val_loss: 0.3487 - val_accuracy: 0.8738
# Epoch 8/30
# 49/49 [==============================] - 1s 10ms/step - loss: 0.1055 - accuracy: 0.9645 - val_loss: 0.3736 - val_accuracy: 0.8713
# Epoch 9/30
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0944 - accuracy: 0.9686 - val_loss: 0.3973 - val_accuracy: 0.8695
# Epoch 10/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0845 - accuracy: 0.9725 - val_loss: 0.4273 - val_accuracy: 0.8648
# Epoch 11/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0773 - accuracy: 0.9748 - val_loss: 0.4807 - val_accuracy: 0.8610
# Epoch 12/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0690 - accuracy: 0.9779 - val_loss: 0.5069 - val_accuracy: 0.8609
# Epoch 13/30
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0628 - accuracy: 0.9812 - val_loss: 0.5223 - val_accuracy: 0.8589
# Epoch 14/30
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0544 - accuracy: 0.9840 - val_loss: 0.5514 - val_accuracy: 0.8586
# Epoch 15/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0522 - accuracy: 0.9846 - val_loss: 0.5966 - val_accuracy: 0.8564
# Epoch 16/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0424 - accuracy: 0.9880 - val_loss: 0.6221 - val_accuracy: 0.8544
# Epoch 17/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0401 - accuracy: 0.9886 - val_loss: 0.6459 - val_accuracy: 0.8520
# Epoch 18/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0342 - accuracy: 0.9901 - val_loss: 0.7012 - val_accuracy: 0.8518
# Epoch 19/30
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0303 - accuracy: 0.9915 - val_loss: 0.7186 - val_accuracy: 0.8500
# Epoch 20/30
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0278 - accuracy: 0.9918 - val_loss: 0.7641 - val_accuracy: 0.8488
# Epoch 21/30
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0239 - accuracy: 0.9933 - val_loss: 0.7970 - val_accuracy: 0.8485
# Epoch 22/30
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0203 - accuracy: 0.9949 - val_loss: 0.8420 - val_accuracy: 0.8468
# Epoch 23/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0185 - accuracy: 0.9950 - val_loss: 0.8806 - val_accuracy: 0.8456
# Epoch 24/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0159 - accuracy: 0.9960 - val_loss: 0.9108 - val_accuracy: 0.8435
# Epoch 25/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0149 - accuracy: 0.9964 - val_loss: 0.9619 - val_accuracy: 0.8363
# Epoch 26/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0130 - accuracy: 0.9968 - val_loss: 0.9842 - val_accuracy: 0.8429
# Epoch 27/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0100 - accuracy: 0.9976 - val_loss: 1.0548 - val_accuracy: 0.8443
# Epoch 28/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0119 - accuracy: 0.9970 - val_loss: 1.0617 - val_accuracy: 0.8426
# Epoch 29/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0098 - accuracy: 0.9973 - val_loss: 1.1029 - val_accuracy: 0.8425
# Epoch 30/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0099 - accuracy: 0.9974 - val_loss: 1.1400 - val_accuracy: 0.8426

# %%
s_history_dict = s_model_history.history

s_loss = s_history_dict['loss']
s_val_loss = s_history_dict['val_loss']
epochs = range(1, len(s_loss) + 1)

fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, b_loss, 'b-', label='train_loss(large)')
ax1.plot(epochs, b_val_loss, 'r-', label='val_loss(large)')
ax1.plot(epochs, loss, 'b--', label='train_loss')
ax1.plot(epochs, val_loss, 'r--', label='val_loss')
ax1.plot(epochs, s_loss, 'b:', label='train_loss(small)')
ax1.plot(epochs, s_val_loss, 'r:', label='val_loss(small)')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

s_accuracy = s_history_dict['accuracy']
s_val_accuracy = s_history_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, b_accuracy, 'b-', label='train_accuracy(large)')
ax2.plot(epochs, b_val_accuracy, 'r-', label='val_accuracy(large)')
ax2.plot(epochs, accuracy, 'b--', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r--', label='val_accuracy')
ax2.plot(epochs, s_accuracy, 'b:', label='train_accuracy(small)')
ax2.plot(epochs, s_val_accuracy, 'r:', label='val_accuracy(small)')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %%
your_model = models.Sequential()
your_model.add(layers.Dense(8, activation='relu', input_shape=(10000, ), name='input2'))
your_model.add(layers.Dense(8, activation='relu', name='hidden2'))
your_model.add(layers.Dense(1, activation='sigmoid', name='output2'))
your_model.compile(optimizer='rmsprop',
                loss='binary_crossentropy',
                metrics=['accuracy'])
your_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input2 (Dense)              (None, 8)                 80008
#
#  hidden2 (Dense)             (None, 8)                 72
#
#  output2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 80089 (312.85 KB)
# Trainable params: 80089 (312.85 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
your_model_history = your_model.fit(x_train, y_train, epochs=30, batch_size=512,  validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 49/49 [==============================] - 2s 44ms/step - loss: 0.4585 - accuracy: 0.8224 - val_loss: 0.3532 - val_accuracy: 0.8768
# Epoch 2/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.2730 - accuracy: 0.9067 - val_loss: 0.3045 - val_accuracy: 0.8806
# Epoch 3/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.2127 - accuracy: 0.9276 - val_loss: 0.2819 - val_accuracy: 0.8878
# Epoch 4/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1806 - accuracy: 0.9376 - val_loss: 0.2906 - val_accuracy: 0.8828
# Epoch 5/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1576 - accuracy: 0.9453 - val_loss: 0.2978 - val_accuracy: 0.8829
# Epoch 6/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1408 - accuracy: 0.9523 - val_loss: 0.3058 - val_accuracy: 0.8804
# Epoch 7/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1269 - accuracy: 0.9573 - val_loss: 0.3214 - val_accuracy: 0.8778
# Epoch 8/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1138 - accuracy: 0.9622 - val_loss: 0.3580 - val_accuracy: 0.8694
# Epoch 9/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1051 - accuracy: 0.9655 - val_loss: 0.3585 - val_accuracy: 0.8716
# Epoch 10/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0953 - accuracy: 0.9696 - val_loss: 0.3792 - val_accuracy: 0.8681
# Epoch 11/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0874 - accuracy: 0.9729 - val_loss: 0.4029 - val_accuracy: 0.8660
# Epoch 12/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0818 - accuracy: 0.9738 - val_loss: 0.4224 - val_accuracy: 0.8646
# Epoch 13/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0728 - accuracy: 0.9778 - val_loss: 0.4716 - val_accuracy: 0.8568
# Epoch 14/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0674 - accuracy: 0.9800 - val_loss: 0.4889 - val_accuracy: 0.8568
# Epoch 15/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0630 - accuracy: 0.9818 - val_loss: 0.5010 - val_accuracy: 0.8567
# Epoch 16/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0570 - accuracy: 0.9837 - val_loss: 0.5192 - val_accuracy: 0.8579
# Epoch 17/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0514 - accuracy: 0.9854 - val_loss: 0.5453 - val_accuracy: 0.8558
# Epoch 18/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0477 - accuracy: 0.9866 - val_loss: 0.5829 - val_accuracy: 0.8522
# Epoch 19/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0428 - accuracy: 0.9890 - val_loss: 0.6067 - val_accuracy: 0.8511
# Epoch 20/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0393 - accuracy: 0.9898 - val_loss: 0.6424 - val_accuracy: 0.8497
# Epoch 21/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0347 - accuracy: 0.9908 - val_loss: 0.6656 - val_accuracy: 0.8493
# Epoch 22/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0326 - accuracy: 0.9918 - val_loss: 0.7223 - val_accuracy: 0.8464
# Epoch 23/30
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0289 - accuracy: 0.9925 - val_loss: 0.7459 - val_accuracy: 0.8459
# Epoch 24/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0255 - accuracy: 0.9940 - val_loss: 0.7686 - val_accuracy: 0.8441
# Epoch 25/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0244 - accuracy: 0.9938 - val_loss: 0.7925 - val_accuracy: 0.8464
# Epoch 26/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0201 - accuracy: 0.9958 - val_loss: 0.8260 - val_accuracy: 0.8461
# Epoch 27/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0181 - accuracy: 0.9964 - val_loss: 0.9192 - val_accuracy: 0.8393
# Epoch 28/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0170 - accuracy: 0.9962 - val_loss: 0.9321 - val_accuracy: 0.8404
# Epoch 29/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0160 - accuracy: 0.9966 - val_loss: 0.9320 - val_accuracy: 0.8423
# Epoch 30/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0123 - accuracy: 0.9978 - val_loss: 0.9701 - val_accuracy: 0.8422

# %%
your_history_dict = your_model_history.history

your_loss = your_history_dict['loss']
your_val_loss = your_history_dict['val_loss']
epochs = range(1, len(your_loss) + 1)

fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, b_loss, 'b-', label='train_loss(large)')
ax1.plot(epochs, b_val_loss, 'r-', label='val_loss(large)')
ax1.plot(epochs, loss, 'b--', label='train_loss')
ax1.plot(epochs, val_loss, 'r--', label='val_loss')
ax1.plot(epochs, your_loss, 'b:', label='train_loss(small)')
ax1.plot(epochs, your_val_loss, 'r:', label='val_loss(small)')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

your_accuracy = your_history_dict['accuracy']
your_val_accuracy = your_history_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, b_accuracy, 'b-', label='train_accuracy(large)')
ax2.plot(epochs, b_val_accuracy, 'r-', label='val_accuracy(large)')
ax2.plot(epochs, accuracy, 'b--', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r--', label='val_accuracy')
ax2.plot(epochs, s_accuracy, 'b:', label='train_accuracy(small)')
ax2.plot(epochs, s_val_accuracy, 'r:', label='val_accuracy(small)')
ax2.plot(epochs, your_accuracy, 'g-', label='train_accuracy(your)')
ax2.plot(epochs, your_val_accuracy, 'g--', label='val_accuracy(your)')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %%
l1_model =  models.Sequential()
l1_model.add(layers.Dense(16, 
                          kernel_regularizer='l1',
                          activation='relu', 
                          input_shape=(10000, )))
l1_model.add(layers.Dense(16, 
                          kernel_regularizer='l1',
                          activation='relu'))
l1_model.add(layers.Dense(1, activation='sigmoid'))
l1_model.compile(optimizer='rmsprop',
                 loss='binary_crossentropy',
                 metrics=['accuracy'])
l1_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                160016
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 160305 (626.19 KB)
# Trainable params: 160305 (626.19 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
l1_model_hist = l1_model.fit(x_train, y_train,
                             epochs=30,
                             batch_size=512,
                             validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 49/49 [==============================] - 3s 50ms/step - loss: 3.7321 - accuracy: 0.5884 - val_loss: 1.9215 - val_accuracy: 0.6096
# Epoch 2/30
# 49/49 [==============================] - 1s 14ms/step - loss: 1.8556 - accuracy: 0.6440 - val_loss: 1.7915 - val_accuracy: 0.6823
# Epoch 3/30
# 49/49 [==============================] - 1s 12ms/step - loss: 1.7508 - accuracy: 0.6834 - val_loss: 1.7149 - val_accuracy: 0.6944
# Epoch 4/30
# 49/49 [==============================] - 1s 12ms/step - loss: 1.6642 - accuracy: 0.7044 - val_loss: 1.6144 - val_accuracy: 0.6910
# Epoch 5/30
# 49/49 [==============================] - 1s 12ms/step - loss: 1.5862 - accuracy: 0.7280 - val_loss: 1.5550 - val_accuracy: 0.7448
# Epoch 6/30
# 49/49 [==============================] - 1s 11ms/step - loss: 1.5150 - accuracy: 0.7566 - val_loss: 1.4766 - val_accuracy: 0.7707
# Epoch 7/30
# 49/49 [==============================] - 1s 11ms/step - loss: 1.4591 - accuracy: 0.7730 - val_loss: 1.4453 - val_accuracy: 0.7839
# Epoch 8/30
# 49/49 [==============================] - 1s 13ms/step - loss: 1.4188 - accuracy: 0.7854 - val_loss: 1.3969 - val_accuracy: 0.7939
# Epoch 9/30
# 49/49 [==============================] - 1s 12ms/step - loss: 1.3900 - accuracy: 0.8008 - val_loss: 1.3886 - val_accuracy: 0.8014
# Epoch 10/30
# 49/49 [==============================] - 0s 10ms/step - loss: 1.3747 - accuracy: 0.8071 - val_loss: 1.3612 - val_accuracy: 0.8085
# Epoch 11/30
# 49/49 [==============================] - 1s 11ms/step - loss: 1.3622 - accuracy: 0.8139 - val_loss: 1.3651 - val_accuracy: 0.8157
# Epoch 12/30
# 49/49 [==============================] - 1s 11ms/step - loss: 1.3518 - accuracy: 0.8198 - val_loss: 1.3407 - val_accuracy: 0.8216
# Epoch 13/30
# 49/49 [==============================] - 1s 10ms/step - loss: 1.3419 - accuracy: 0.8254 - val_loss: 1.3487 - val_accuracy: 0.8265
# Epoch 14/30
# 49/49 [==============================] - 1s 12ms/step - loss: 1.3347 - accuracy: 0.8311 - val_loss: 1.3279 - val_accuracy: 0.8317
# Epoch 15/30
# 49/49 [==============================] - 0s 10ms/step - loss: 1.3280 - accuracy: 0.8362 - val_loss: 1.3386 - val_accuracy: 0.8336
# Epoch 16/30
# 49/49 [==============================] - 1s 11ms/step - loss: 1.3236 - accuracy: 0.8408 - val_loss: 1.3383 - val_accuracy: 0.8222
# Epoch 17/30
# 49/49 [==============================] - 0s 10ms/step - loss: 1.3193 - accuracy: 0.8402 - val_loss: 1.3306 - val_accuracy: 0.8379
# Epoch 18/30
# 49/49 [==============================] - 1s 11ms/step - loss: 1.3150 - accuracy: 0.8435 - val_loss: 1.3349 - val_accuracy: 0.8265
# Epoch 19/30
# 49/49 [==============================] - 1s 12ms/step - loss: 1.3140 - accuracy: 0.8452 - val_loss: 1.3224 - val_accuracy: 0.8441
# Epoch 20/30
# 49/49 [==============================] - 1s 11ms/step - loss: 1.3105 - accuracy: 0.8480 - val_loss: 1.3028 - val_accuracy: 0.8437
# Epoch 21/30
# 49/49 [==============================] - 1s 11ms/step - loss: 1.3079 - accuracy: 0.8492 - val_loss: 1.3360 - val_accuracy: 0.8352
# Epoch 22/30
# 49/49 [==============================] - 1s 13ms/step - loss: 1.3068 - accuracy: 0.8494 - val_loss: 1.2982 - val_accuracy: 0.8468
# Epoch 23/30
# 49/49 [==============================] - 1s 13ms/step - loss: 1.3059 - accuracy: 0.8483 - val_loss: 1.3149 - val_accuracy: 0.8474
# Epoch 24/30
# 49/49 [==============================] - 1s 12ms/step - loss: 1.3031 - accuracy: 0.8507 - val_loss: 1.2956 - val_accuracy: 0.8485
# Epoch 25/30
# 49/49 [==============================] - 1s 16ms/step - loss: 1.3019 - accuracy: 0.8516 - val_loss: 1.3187 - val_accuracy: 0.8448
# Epoch 26/30
# 49/49 [==============================] - 1s 14ms/step - loss: 1.3010 - accuracy: 0.8523 - val_loss: 1.3056 - val_accuracy: 0.8441
# Epoch 27/30
# 49/49 [==============================] - 1s 12ms/step - loss: 1.2980 - accuracy: 0.8546 - val_loss: 1.3078 - val_accuracy: 0.8493
# Epoch 28/30
# 49/49 [==============================] - 1s 12ms/step - loss: 1.2995 - accuracy: 0.8528 - val_loss: 1.3066 - val_accuracy: 0.8452
# Epoch 29/30
# 49/49 [==============================] - 1s 13ms/step - loss: 1.2968 - accuracy: 0.8546 - val_loss: 1.3061 - val_accuracy: 0.8530
# Epoch 30/30
# 49/49 [==============================] - 1s 13ms/step - loss: 1.2984 - accuracy: 0.8521 - val_loss: 1.3023 - val_accuracy: 0.8468

# %%
l1_val_loss = l1_model_hist.history['val_loss']

epochs = range(1, 31)
plt.plot(epochs, val_loss, 'k--', label='Model')
plt.plot(epochs, l1_val_loss, 'b--', label='L1-regularized')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()
plt.show()

# %%
l2_model =  models.Sequential()
l2_model.add(layers.Dense(16, 
                          kernel_regularizer='l2',
                          activation='relu', 
                          input_shape=(10000, )))
l2_model.add(layers.Dense(16, 
                          kernel_regularizer='l2',
                          activation='relu'))
l2_model.add(layers.Dense(1, activation='sigmoid'))
l2_model.compile(optimizer='rmsprop',
                 loss='binary_crossentropy',
                 metrics=['accuracy'])
l2_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 16)                160016
#
#  dense_4 (Dense)             (None, 16)                272
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 160305 (626.19 KB)
# Trainable params: 160305 (626.19 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
l2_model_hist = l2_model.fit(x_train, y_train,
                             epochs=30,
                             batch_size=512,
                             validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 49/49 [==============================] - 3s 54ms/step - loss: 0.7002 - accuracy: 0.8145 - val_loss: 0.5626 - val_accuracy: 0.8768
# Epoch 2/30
# 49/49 [==============================] - 1s 17ms/step - loss: 0.5208 - accuracy: 0.8816 - val_loss: 0.5036 - val_accuracy: 0.8804
# Epoch 3/30
# 49/49 [==============================] - 1s 15ms/step - loss: 0.4757 - accuracy: 0.8866 - val_loss: 0.4750 - val_accuracy: 0.8808
# Epoch 4/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.4508 - accuracy: 0.8883 - val_loss: 0.4548 - val_accuracy: 0.8824
# Epoch 5/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.4313 - accuracy: 0.8917 - val_loss: 0.4466 - val_accuracy: 0.8797
# Epoch 6/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.4138 - accuracy: 0.8956 - val_loss: 0.4578 - val_accuracy: 0.8662
# Epoch 7/30
# 49/49 [==============================] - 1s 15ms/step - loss: 0.4049 - accuracy: 0.8950 - val_loss: 0.4321 - val_accuracy: 0.8786
# Epoch 8/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3973 - accuracy: 0.8963 - val_loss: 0.4441 - val_accuracy: 0.8674
# Epoch 9/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.3897 - accuracy: 0.8999 - val_loss: 0.4477 - val_accuracy: 0.8636
# Epoch 10/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.3799 - accuracy: 0.9006 - val_loss: 0.4566 - val_accuracy: 0.8549
# Epoch 11/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3845 - accuracy: 0.8969 - val_loss: 0.4193 - val_accuracy: 0.8774
# Epoch 12/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3737 - accuracy: 0.9012 - val_loss: 0.4265 - val_accuracy: 0.8724
# Epoch 13/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.3697 - accuracy: 0.9018 - val_loss: 0.4030 - val_accuracy: 0.8841
# Epoch 14/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3718 - accuracy: 0.8997 - val_loss: 0.4139 - val_accuracy: 0.8760
# Epoch 15/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3629 - accuracy: 0.9043 - val_loss: 0.4059 - val_accuracy: 0.8797
# Epoch 16/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.3626 - accuracy: 0.9013 - val_loss: 0.3967 - val_accuracy: 0.8851
# Epoch 17/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3617 - accuracy: 0.9020 - val_loss: 0.3999 - val_accuracy: 0.8820
# Epoch 18/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3548 - accuracy: 0.9046 - val_loss: 0.4345 - val_accuracy: 0.8625
# Epoch 19/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3564 - accuracy: 0.9018 - val_loss: 0.4014 - val_accuracy: 0.8801
# Epoch 20/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3561 - accuracy: 0.9023 - val_loss: 0.4278 - val_accuracy: 0.8638
# Epoch 21/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3505 - accuracy: 0.9057 - val_loss: 0.4079 - val_accuracy: 0.8761
# Epoch 22/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3482 - accuracy: 0.9065 - val_loss: 0.3893 - val_accuracy: 0.8842
# Epoch 23/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3455 - accuracy: 0.9068 - val_loss: 0.4282 - val_accuracy: 0.8639
# Epoch 24/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3478 - accuracy: 0.9050 - val_loss: 0.4222 - val_accuracy: 0.8653
# Epoch 25/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3445 - accuracy: 0.9060 - val_loss: 0.4181 - val_accuracy: 0.8662
# Epoch 26/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3455 - accuracy: 0.9062 - val_loss: 0.3967 - val_accuracy: 0.8794
# Epoch 27/30
# 49/49 [==============================] - 1s 12ms/step - loss: 0.3420 - accuracy: 0.9072 - val_loss: 0.3845 - val_accuracy: 0.8837
# Epoch 28/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3453 - accuracy: 0.9035 - val_loss: 0.3970 - val_accuracy: 0.8764
# Epoch 29/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3391 - accuracy: 0.9083 - val_loss: 0.3852 - val_accuracy: 0.8831
# Epoch 30/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3358 - accuracy: 0.9094 - val_loss: 0.4102 - val_accuracy: 0.8690

# %%
l2_val_loss = l2_model_hist.history['val_loss']

epochs = range(1, 31)
plt.plot(epochs, val_loss, 'k--', label='Model')
plt.plot(epochs, l2_val_loss, 'r--', label='L2-regularized')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()
plt.show()

# %%
l1_l2_model =  models.Sequential()
l1_l2_model.add(layers.Dense(16, 
                             kernel_regularizer='l1_l2',
                             activation='relu', input_shape=(10000, )))
l1_l2_model.add(layers.Dense(16, 
                             kernel_regularizer='l1_l2',
                             activation='relu'))
l1_l2_model.add(layers.Dense(1, activation='sigmoid'))
l1_l2_model.compile(optimizer='rmsprop',
                    loss='binary_crossentropy',
                    metrics=['accuracy'])
l1_l2_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 16)                160016
#
#  dense_7 (Dense)             (None, 16)                272
#
#  dense_8 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 160305 (626.19 KB)
# Trainable params: 160305 (626.19 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
l1_l2_model_hist = l1_l2_model.fit(x_train, y_train,
                                  epochs=30,
                                  batch_size=512,
                                  validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 49/49 [==============================] - 3s 54ms/step - loss: 3.8681 - accuracy: 0.5264 - val_loss: 2.0227 - val_accuracy: 0.5912
# Epoch 2/30
# 49/49 [==============================] - 1s 14ms/step - loss: 1.9394 - accuracy: 0.5654 - val_loss: 1.8603 - val_accuracy: 0.6663
# Epoch 3/30
# 49/49 [==============================] - 1s 12ms/step - loss: 1.8161 - accuracy: 0.6008 - val_loss: 1.7713 - val_accuracy: 0.5007
# Epoch 4/30
# 49/49 [==============================] - 1s 13ms/step - loss: 1.7157 - accuracy: 0.5900 - val_loss: 1.6642 - val_accuracy: 0.5237
# Epoch 5/30
# 49/49 [==============================] - 1s 13ms/step - loss: 1.6365 - accuracy: 0.5665 - val_loss: 1.6094 - val_accuracy: 0.6212
# Epoch 6/30
# 49/49 [==============================] - 1s 13ms/step - loss: 1.5770 - accuracy: 0.5517 - val_loss: 1.5485 - val_accuracy: 0.5000
# Epoch 7/30
# 49/49 [==============================] - 1s 14ms/step - loss: 1.5348 - accuracy: 0.5052 - val_loss: 1.5221 - val_accuracy: 0.5007
# Epoch 8/30
# 49/49 [==============================] - 1s 12ms/step - loss: 1.5083 - accuracy: 0.5085 - val_loss: 1.4964 - val_accuracy: 0.5000
# Epoch 9/30
# 49/49 [==============================] - 1s 11ms/step - loss: 1.4962 - accuracy: 0.4994 - val_loss: 1.4979 - val_accuracy: 0.5000
# Epoch 10/30
# 49/49 [==============================] - 1s 11ms/step - loss: 1.4949 - accuracy: 0.5026 - val_loss: 1.4921 - val_accuracy: 0.5000
# Epoch 11/30
# 49/49 [==============================] - 1s 11ms/step - loss: 1.4949 - accuracy: 0.5002 - val_loss: 1.4973 - val_accuracy: 0.5000
# Epoch 12/30
# 49/49 [==============================] - 1s 13ms/step - loss: 1.4949 - accuracy: 0.4996 - val_loss: 1.4926 - val_accuracy: 0.5000
# Epoch 13/30
# 49/49 [==============================] - 1s 12ms/step - loss: 1.4949 - accuracy: 0.4959 - val_loss: 1.4969 - val_accuracy: 0.5000
# Epoch 14/30
# 49/49 [==============================] - 1s 12ms/step - loss: 1.4949 - accuracy: 0.4996 - val_loss: 1.4930 - val_accuracy: 0.5000
# Epoch 15/30
# 49/49 [==============================] - 1s 11ms/step - loss: 1.4949 - accuracy: 0.4950 - val_loss: 1.4966 - val_accuracy: 0.5000
# Epoch 16/30
# 49/49 [==============================] - 1s 11ms/step - loss: 1.4949 - accuracy: 0.5000 - val_loss: 1.4934 - val_accuracy: 0.5000
# Epoch 17/30
# 49/49 [==============================] - 1s 12ms/step - loss: 1.4949 - accuracy: 0.4972 - val_loss: 1.4963 - val_accuracy: 0.5000
# Epoch 18/30
# 49/49 [==============================] - 1s 12ms/step - loss: 1.4949 - accuracy: 0.4964 - val_loss: 1.4935 - val_accuracy: 0.5000
# Epoch 19/30
# 49/49 [==============================] - 1s 12ms/step - loss: 1.4948 - accuracy: 0.5002 - val_loss: 1.4960 - val_accuracy: 0.5000
# Epoch 20/30
# 49/49 [==============================] - 1s 12ms/step - loss: 1.4949 - accuracy: 0.5000 - val_loss: 1.4938 - val_accuracy: 0.5000
# Epoch 21/30
# 49/49 [==============================] - 1s 12ms/step - loss: 1.4949 - accuracy: 0.4954 - val_loss: 1.4958 - val_accuracy: 0.5000
# Epoch 22/30
# 49/49 [==============================] - 1s 11ms/step - loss: 1.4949 - accuracy: 0.4994 - val_loss: 1.4940 - val_accuracy: 0.5000
# Epoch 23/30
# 49/49 [==============================] - 1s 12ms/step - loss: 1.4948 - accuracy: 0.5004 - val_loss: 1.4956 - val_accuracy: 0.5000
# Epoch 24/30
# 49/49 [==============================] - 1s 11ms/step - loss: 1.4949 - accuracy: 0.5008 - val_loss: 1.4941 - val_accuracy: 0.5000
# Epoch 25/30
# 49/49 [==============================] - 1s 10ms/step - loss: 1.4948 - accuracy: 0.4994 - val_loss: 1.4955 - val_accuracy: 0.5000
# Epoch 26/30
# 49/49 [==============================] - 1s 12ms/step - loss: 1.4949 - accuracy: 0.4968 - val_loss: 1.4942 - val_accuracy: 0.5000
# Epoch 27/30
# 49/49 [==============================] - 1s 10ms/step - loss: 1.4949 - accuracy: 0.5006 - val_loss: 1.4954 - val_accuracy: 0.5000
# Epoch 28/30
# 49/49 [==============================] - 1s 11ms/step - loss: 1.4949 - accuracy: 0.4953 - val_loss: 1.4944 - val_accuracy: 0.5000
# Epoch 29/30
# 49/49 [==============================] - 1s 11ms/step - loss: 1.4949 - accuracy: 0.4960 - val_loss: 1.4952 - val_accuracy: 0.5000
# Epoch 30/30
# 49/49 [==============================] - 0s 10ms/step - loss: 1.4949 - accuracy: 0.4940 - val_loss: 1.4944 - val_accuracy: 0.5000

# %%
l1_l2_val_loss = l1_l2_model_hist.history['val_loss']

epochs = range(1, 31)
plt.plot(epochs, val_loss, 'k--', label='Model')
plt.plot(epochs, l1_l2_val_loss, 'g--', label='L1_L2-regularized')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()
plt.show()

# %%
epochs = range(1, 31)
plt.plot(epochs, val_loss, 'k--', label='Model')
plt.plot(epochs, l1_val_loss, 'b--', label='L1-regularized')
plt.plot(epochs, l2_val_loss, 'r--', label='L2-regularized')
plt.plot(epochs, l1_l2_val_loss, 'g--', label='L1_L2-regularized')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()
plt.show()

# %%
from tensorflow import keras

your_model =  models.Sequential()
your_model.add(layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.01), activation='relu', input_shape=(10000, )))
your_model.add(layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.01), activation='relu'))
your_model.add(layers.Dense(1, activation='sigmoid'))
your_model.compile(optimizer='rmsprop',
                    loss='binary_crossentropy',
                    metrics=['accuracy'])
your_model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 16)                160016
#
#  dense_10 (Dense)            (None, 16)                272
#
#  dense_11 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 160305 (626.19 KB)
# Trainable params: 160305 (626.19 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
your_model_hist = your_model.fit(x_train, y_train,
                                 epochs=30,
                                 batch_size=512,
                                 validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 49/49 [==============================] - 3s 53ms/step - loss: 0.6862 - accuracy: 0.8146 - val_loss: 0.5484 - val_accuracy: 0.8756
# Epoch 2/30
# 49/49 [==============================] - 1s 15ms/step - loss: 0.5061 - accuracy: 0.8853 - val_loss: 0.5263 - val_accuracy: 0.8560
# Epoch 3/30
# 49/49 [==============================] - 1s 12ms/step - loss: 0.4685 - accuracy: 0.8882 - val_loss: 0.4697 - val_accuracy: 0.8823
# Epoch 4/30
# 49/49 [==============================] - 1s 12ms/step - loss: 0.4406 - accuracy: 0.8944 - val_loss: 0.4602 - val_accuracy: 0.8784
# Epoch 5/30
# 49/49 [==============================] - 1s 12ms/step - loss: 0.4239 - accuracy: 0.8958 - val_loss: 0.4475 - val_accuracy: 0.8788
# Epoch 6/30
# 49/49 [==============================] - 1s 12ms/step - loss: 0.4128 - accuracy: 0.8964 - val_loss: 0.4315 - val_accuracy: 0.8834
# Epoch 7/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.4032 - accuracy: 0.8975 - val_loss: 0.4251 - val_accuracy: 0.8838
# Epoch 8/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.3963 - accuracy: 0.8986 - val_loss: 0.4208 - val_accuracy: 0.8824
# Epoch 9/30
# 49/49 [==============================] - 1s 12ms/step - loss: 0.3895 - accuracy: 0.8972 - val_loss: 0.4199 - val_accuracy: 0.8820
# Epoch 10/30
# 49/49 [==============================] - 1s 12ms/step - loss: 0.3842 - accuracy: 0.9007 - val_loss: 0.4254 - val_accuracy: 0.8766
# Epoch 11/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3835 - accuracy: 0.8985 - val_loss: 0.4199 - val_accuracy: 0.8780
# Epoch 12/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3722 - accuracy: 0.9043 - val_loss: 0.4286 - val_accuracy: 0.8715
# Epoch 13/30
# 49/49 [==============================] - 1s 12ms/step - loss: 0.3735 - accuracy: 0.9010 - val_loss: 0.4254 - val_accuracy: 0.8734
# Epoch 14/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3717 - accuracy: 0.9012 - val_loss: 0.4363 - val_accuracy: 0.8672
# Epoch 15/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.3684 - accuracy: 0.9014 - val_loss: 0.4024 - val_accuracy: 0.8825
# Epoch 16/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3639 - accuracy: 0.9036 - val_loss: 0.4090 - val_accuracy: 0.8794
# Epoch 17/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.3585 - accuracy: 0.9051 - val_loss: 0.4333 - val_accuracy: 0.8649
# Epoch 18/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3598 - accuracy: 0.9039 - val_loss: 0.4008 - val_accuracy: 0.8802
# Epoch 19/30
# 49/49 [==============================] - 1s 10ms/step - loss: 0.3566 - accuracy: 0.9062 - val_loss: 0.3970 - val_accuracy: 0.8826
# Epoch 20/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.3496 - accuracy: 0.9078 - val_loss: 0.4034 - val_accuracy: 0.8790
# Epoch 21/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.3514 - accuracy: 0.9052 - val_loss: 0.4212 - val_accuracy: 0.8688
# Epoch 22/30
# 49/49 [==============================] - 1s 10ms/step - loss: 0.3433 - accuracy: 0.9091 - val_loss: 0.3924 - val_accuracy: 0.8841
# Epoch 23/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.3460 - accuracy: 0.9064 - val_loss: 0.3918 - val_accuracy: 0.8816
# Epoch 24/30
# 49/49 [==============================] - 1s 10ms/step - loss: 0.3387 - accuracy: 0.9085 - val_loss: 0.3904 - val_accuracy: 0.8825
# Epoch 25/30
# 49/49 [==============================] - 1s 10ms/step - loss: 0.3418 - accuracy: 0.9087 - val_loss: 0.3879 - val_accuracy: 0.8846
# Epoch 26/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3373 - accuracy: 0.9111 - val_loss: 0.3863 - val_accuracy: 0.8840
# Epoch 27/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.3373 - accuracy: 0.9095 - val_loss: 0.3995 - val_accuracy: 0.8767
# Epoch 28/30
# 49/49 [==============================] - 1s 10ms/step - loss: 0.3360 - accuracy: 0.9096 - val_loss: 0.4299 - val_accuracy: 0.8585
# Epoch 29/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3289 - accuracy: 0.9129 - val_loss: 0.4385 - val_accuracy: 0.8586
# Epoch 30/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.3305 - accuracy: 0.9106 - val_loss: 0.4403 - val_accuracy: 0.8532

# %%
your_val_loss = your_model_hist.history['val_loss']

epochs = range(1, 31)
plt.plot(epochs, val_loss, 'k--', label='Model')
plt.plot(epochs, l1_val_loss, 'b--', label='L1-regularized')
plt.plot(epochs, l2_val_loss, 'r--', label='L2-regularized')
plt.plot(epochs, l1_l2_val_loss, 'g--', label='L1_L2-regularized')
plt.plot(epochs, your_val_loss, 'y--', label='Your L2-regularized')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()
plt.show()

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000, )))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 16)                160016
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_13 (Dense)            (None, 16)                272
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_14 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 160305 (626.19 KB)
# Trainable params: 160305 (626.19 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
drop_20_history = model.fit(x_train, y_train,
                            epochs=30,
                            batch_size=512,
                            validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 49/49 [==============================] - 3s 51ms/step - loss: 0.5302 - accuracy: 0.7582 - val_loss: 0.3759 - val_accuracy: 0.8744
# Epoch 2/30
# 49/49 [==============================] - 1s 17ms/step - loss: 0.3282 - accuracy: 0.8806 - val_loss: 0.2911 - val_accuracy: 0.8893
# Epoch 3/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.2490 - accuracy: 0.9107 - val_loss: 0.2819 - val_accuracy: 0.8862
# Epoch 4/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.2066 - accuracy: 0.9278 - val_loss: 0.2835 - val_accuracy: 0.8884
# Epoch 5/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1713 - accuracy: 0.9405 - val_loss: 0.2912 - val_accuracy: 0.8852
# Epoch 6/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.1474 - accuracy: 0.9487 - val_loss: 0.3143 - val_accuracy: 0.8822
# Epoch 7/30
# 49/49 [==============================] - 1s 10ms/step - loss: 0.1267 - accuracy: 0.9584 - val_loss: 0.3391 - val_accuracy: 0.8792
# Epoch 8/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.1047 - accuracy: 0.9658 - val_loss: 0.3757 - val_accuracy: 0.8754
# Epoch 9/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0894 - accuracy: 0.9710 - val_loss: 0.4081 - val_accuracy: 0.8742
# Epoch 10/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0774 - accuracy: 0.9760 - val_loss: 0.4457 - val_accuracy: 0.8709
# Epoch 11/30
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0639 - accuracy: 0.9793 - val_loss: 0.4845 - val_accuracy: 0.8704
# Epoch 12/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0559 - accuracy: 0.9833 - val_loss: 0.5366 - val_accuracy: 0.8700
# Epoch 13/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0483 - accuracy: 0.9850 - val_loss: 0.5715 - val_accuracy: 0.8678
# Epoch 14/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0387 - accuracy: 0.9884 - val_loss: 0.6221 - val_accuracy: 0.8680
# Epoch 15/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0352 - accuracy: 0.9896 - val_loss: 0.6627 - val_accuracy: 0.8673
# Epoch 16/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0291 - accuracy: 0.9916 - val_loss: 0.7586 - val_accuracy: 0.8653
# Epoch 17/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0273 - accuracy: 0.9923 - val_loss: 0.7465 - val_accuracy: 0.8672
# Epoch 18/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0238 - accuracy: 0.9932 - val_loss: 0.8091 - val_accuracy: 0.8657
# Epoch 19/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0200 - accuracy: 0.9950 - val_loss: 0.8814 - val_accuracy: 0.8628
# Epoch 20/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0210 - accuracy: 0.9944 - val_loss: 0.9004 - val_accuracy: 0.8616
# Epoch 21/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0220 - accuracy: 0.9938 - val_loss: 0.9297 - val_accuracy: 0.8638
# Epoch 22/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0197 - accuracy: 0.9949 - val_loss: 0.9657 - val_accuracy: 0.8642
# Epoch 23/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0190 - accuracy: 0.9950 - val_loss: 0.9819 - val_accuracy: 0.8626
# Epoch 24/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0218 - accuracy: 0.9951 - val_loss: 1.0095 - val_accuracy: 0.8633
# Epoch 25/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0189 - accuracy: 0.9960 - val_loss: 1.0665 - val_accuracy: 0.8635
# Epoch 26/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0222 - accuracy: 0.9950 - val_loss: 1.0306 - val_accuracy: 0.8638
# Epoch 27/30
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0179 - accuracy: 0.9958 - val_loss: 1.1325 - val_accuracy: 0.8614
# Epoch 28/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0189 - accuracy: 0.9951 - val_loss: 1.1884 - val_accuracy: 0.8584
# Epoch 29/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0197 - accuracy: 0.9954 - val_loss: 1.1323 - val_accuracy: 0.8624
# Epoch 30/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0206 - accuracy: 0.9953 - val_loss: 1.1299 - val_accuracy: 0.8615

# %%
drop_20_dict = drop_20_history.history

drop_20_loss = drop_20_dict['loss']
drop_20_val_loss = drop_20_dict['val_loss']
epochs = range(1, len(loss) + 1)

fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.plot(epochs, drop_20_loss, 'b--', label='train_loss (dropout 20%)')
ax1.plot(epochs, drop_20_val_loss, 'r--', label='val_loss (dropout 20%)')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

drop_20_accuracy = drop_20_dict['accuracy']
drop_20_val_accuracy = drop_20_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, accuracy, 'b-', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r-', label='val_accuracy')
ax2.plot(epochs, drop_20_accuracy, 'b--', label='train_accuracy (dropout 20%)')
ax2.plot(epochs, drop_20_val_accuracy, 'r--', label='val_accuracy (dropout 20%)')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000, )))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 16)                160016
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  dense_16 (Dense)            (None, 16)                272
#
#  dropout_3 (Dropout)         (None, 16)                0
#
#  dense_17 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 160305 (626.19 KB)
# Trainable params: 160305 (626.19 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
drop_50_history = model.fit(x_train, y_train,
                            epochs=30,
                            batch_size=512,
                            validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 49/49 [==============================] - 3s 48ms/step - loss: 0.6125 - accuracy: 0.6582 - val_loss: 0.4868 - val_accuracy: 0.8358
# Epoch 2/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.4656 - accuracy: 0.7975 - val_loss: 0.3585 - val_accuracy: 0.8830
# Epoch 3/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3712 - accuracy: 0.8581 - val_loss: 0.2941 - val_accuracy: 0.8899
# Epoch 4/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.3093 - accuracy: 0.8859 - val_loss: 0.2759 - val_accuracy: 0.8905
# Epoch 5/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.2685 - accuracy: 0.9046 - val_loss: 0.2752 - val_accuracy: 0.8902
# Epoch 6/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.2356 - accuracy: 0.9169 - val_loss: 0.2829 - val_accuracy: 0.8890
# Epoch 7/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.2129 - accuracy: 0.9255 - val_loss: 0.3075 - val_accuracy: 0.8854
# Epoch 8/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1913 - accuracy: 0.9324 - val_loss: 0.3206 - val_accuracy: 0.8850
# Epoch 9/30
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1794 - accuracy: 0.9381 - val_loss: 0.3417 - val_accuracy: 0.8836
# Epoch 10/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1692 - accuracy: 0.9421 - val_loss: 0.3522 - val_accuracy: 0.8818
# Epoch 11/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1609 - accuracy: 0.9454 - val_loss: 0.3667 - val_accuracy: 0.8824
# Epoch 12/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1464 - accuracy: 0.9492 - val_loss: 0.4000 - val_accuracy: 0.8801
# Epoch 13/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1397 - accuracy: 0.9533 - val_loss: 0.4260 - val_accuracy: 0.8756
# Epoch 14/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.1384 - accuracy: 0.9516 - val_loss: 0.4344 - val_accuracy: 0.8780
# Epoch 15/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1308 - accuracy: 0.9545 - val_loss: 0.4695 - val_accuracy: 0.8776
# Epoch 16/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.1202 - accuracy: 0.9582 - val_loss: 0.4926 - val_accuracy: 0.8766
# Epoch 17/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.1238 - accuracy: 0.9587 - val_loss: 0.4883 - val_accuracy: 0.8711
# Epoch 18/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.1198 - accuracy: 0.9588 - val_loss: 0.5085 - val_accuracy: 0.8740
# Epoch 19/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.1185 - accuracy: 0.9619 - val_loss: 0.5287 - val_accuracy: 0.8721
# Epoch 20/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.1132 - accuracy: 0.9621 - val_loss: 0.5427 - val_accuracy: 0.8711
# Epoch 21/30
# 49/49 [==============================] - 1s 10ms/step - loss: 0.1122 - accuracy: 0.9622 - val_loss: 0.5730 - val_accuracy: 0.8712
# Epoch 22/30
# 49/49 [==============================] - 1s 10ms/step - loss: 0.1059 - accuracy: 0.9643 - val_loss: 0.6139 - val_accuracy: 0.8720
# Epoch 23/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.1097 - accuracy: 0.9649 - val_loss: 0.6289 - val_accuracy: 0.8694
# Epoch 24/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.1013 - accuracy: 0.9664 - val_loss: 0.6494 - val_accuracy: 0.8711
# Epoch 25/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.1106 - accuracy: 0.9636 - val_loss: 0.6645 - val_accuracy: 0.8704
# Epoch 26/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.1040 - accuracy: 0.9646 - val_loss: 0.6631 - val_accuracy: 0.8705
# Epoch 27/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0987 - accuracy: 0.9663 - val_loss: 0.6870 - val_accuracy: 0.8708
# Epoch 28/30
# 49/49 [==============================] - 1s 11ms/step - loss: 0.1065 - accuracy: 0.9662 - val_loss: 0.7071 - val_accuracy: 0.8700
# Epoch 29/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1022 - accuracy: 0.9658 - val_loss: 0.6803 - val_accuracy: 0.8664
# Epoch 30/30
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1033 - accuracy: 0.9673 - val_loss: 0.7034 - val_accuracy: 0.8689

# %%
drop_50_dict = drop_50_history.history

drop_50_loss = drop_50_dict['loss']
drop_50_val_loss = drop_50_dict['val_loss']
epochs = range(1, len(loss) + 1)

fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.plot(epochs, drop_20_loss, 'b--', label='train_loss (dropout 20%)')
ax1.plot(epochs, drop_20_val_loss, 'r--', label='val_loss (dropout 20%)')
ax1.plot(epochs, drop_50_loss, 'b:', label='train_loss (dropout 50%)')
ax1.plot(epochs, drop_50_val_loss, 'r:', label='val_loss (dropout 50%)')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

drop_50_accuracy = drop_50_dict['accuracy']
drop_50_val_accuracy = drop_50_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, accuracy, 'b-', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r-', label='val_accuracy')
ax2.plot(epochs, drop_20_accuracy, 'b--', label='train_accuracy (dropout 20%)')
ax2.plot(epochs, drop_20_val_accuracy, 'r--', label='val_accuracy (dropout 20%)')
ax2.plot(epochs, drop_50_accuracy, 'b:', label='train_accuracy (dropout 50%)')
ax2.plot(epochs, drop_50_val_accuracy, 'r:', label='val_accuracy (dropout 50%)')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()
